# %% [markdown]
# ## **Desafio 1** - Utilizando parâmetros do json_normalize
#
# Você recebeu a tarefa de normalizar o seguinte arquivo JSON chamado [informacoes.json](https://caelum-online-public.s3.amazonaws.com/2929-pandas/informacoes.json), referente a algumas informações de identificação de um cliente. Sua tarefa é normalizar o arquivo em um dataframe.

# %%
import pandas as pd
import json

# %%
with open('informacoes.json') as a:
  info_json = json.load(a)

# %%
info_json
# Out:
# {'nome': 'João',
#  'idade': 28,
#  'enderecos': [{'tipo': 'casa',
#    'rua': 'Rua A',
#    'numero': 123,
#    'cidade': 'São Paulo'},
#   {'tipo': 'trabalho',
#    'rua': 'Rua B',
#    'numero': 456,
#    'cidade': 'Rio de Janeiro'}]}

# %%
info_norm = pd.json_normalize(info_json, record_path='enderecos', meta=['nome','idade'])
info_norm
# Out:
#        tipo    rua  numero          cidade  nome idade
# 0      casa  Rua A     123       São Paulo  João    28
# 1  trabalho  Rua B     456  Rio de Janeiro  João    28

# %% [markdown]
# ## **Desafio 2** - Tratando dados
#
# Você recebeu um arquivo chamado [dados.json](https://caelum-online-public.s3.amazonaws.com/2929-pandas/dados.json). Sua tarefa é realizar alguns tratamentos e deixar esse arquivo JSON como um Pandas DataFrame, sem dados vazios e com a tipagem das colunas de forma correta.

# %%
with open('dados.json') as a:
  dados_json = json.load(a)

# %%
dados_json
# Out:
# {'pessoas': [{'nome': 'João',
#    'idade': '25',
#    'endereco': {'rua': 'Rua A', 'numero': 123, 'cidade': 'São Paulo'},
#    'telefones': ['11 1111-1111', '11 2222-2222']},
#   {'nome': 'Maria',
#    'idade': 30,
#    'endereco': {'rua': '', 'numero': 456, 'cidade': 'Rio de Janeiro'},
#    'telefones': ['21 3333-3333']}]}

# %%
dados_norm = pd.json_normalize(dados_json, record_path='pessoas')
dados_norm
# Out:
#     nome idade                     telefones endereco.rua  endereco.numero  \
# 0   João    25  [11 1111-1111, 11 2222-2222]        Rua A              123
# 1  Maria    30                [21 3333-3333]                           456
#
#   endereco.cidade
# 0       São Paulo
# 1  Rio de Janeiro

# %%
dados_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nome             2 non-null      object
#  1   idade            2 non-null      object
#  2   telefones        2 non-null      object
#  3   endereco.rua     2 non-null      object
#  4   endereco.numero  2 non-null      int64
#  5   endereco.cidade  2 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 224.0+ bytes

# %%
dados_norm['idade'] = dados_norm['idade'].astype(int)
dados_norm['endereco.numero'] = dados_norm['endereco.numero'].astype(int)

# %%
dados_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nome             2 non-null      object
#  1   idade            2 non-null      int64
#  2   telefones        2 non-null      object
#  3   endereco.rua     2 non-null      object
#  4   endereco.numero  2 non-null      int64
#  5   endereco.cidade  2 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 224.0+ bytes

# %%
dados_filtrados = dados_norm.query("`endereco.rua` != ''")
dados_filtrados
# Out:
#    nome  idade                     telefones endereco.rua  endereco.numero  \
# 0  João     25  [11 1111-1111, 11 2222-2222]        Rua A              123
#
#   endereco.cidade
# 0       São Paulo

# %% [markdown]
# Obs: A coluna `endereco.rua` deve estar entre crases para que o Pandas possa interpretá-la corretamente como uma coluna com nome contendo pontos.

# %% [markdown]
# ## **Desafio 3** - Tratando uma base de dados

# %% [markdown]
# Para facilitar a análise dos dados de cadastro de cursos de uma plataforma, você recebeu um arquivo chamado [cursos_cadastrados.json](https://caelum-online-public.s3.amazonaws.com/2929-pandas/cursos_cadastrados.json). Você foi informado que esses dados podem apresentar problemas que podem prejudicar a análise e interpretação correta dos dados.
#
# Para resolver isso, foi solicitado que você identifique e remova as amostras que apresentam os seguintes problemas:
#
# * Valores nulos: são valores ausentes em algumas das colunas que devem ser preenchidos para que a análise seja correta.
# * Duplicatas: registros iguais que podem prejudicar a análise dos dados, já que estão representando a mesma informação.
# * Strings vazias: valores de texto que não apresentam nenhum conteúdo escrito, o que pode dificultar a análise de dados, principalmente se a coluna tiver muitos valores assim.
# * Conversão de tipos: algumas colunas do arquivo podem estar no tipo de dados errado, como texto em vez de número, o que pode prejudicar a análise. Nesse caso você deve realizar a conversão para o tipo correto de cada coluna.
#
#
# Dentro desse contexto, você precisará de uma abordagem sistemática para limpar os dados.

# %%
with open('cursos_cadastrados.json') as a:
  cursos_json = json.load(a)

# %%
cursos_json
# Out:
# [{'curso': 'Introdução à programação',
#   'categoria': 'Programação',
#   'carga_horaria': '20 horas',
#   'concluintes': 100,
#   'data_inicio': '2022-01-01',
#   'data_conclusao': '2022-01-20',
#   'descricao': 'Curso introdutório à programação com Python',
#   'preco': '99.90',
#   'instrutor': {'nome': 'João Silva',
#    'email': 'joao.silva@emailaleatorio.com',
#    'telefone': '(11) 9999-9999'}},
#  {'curso': 'Excel para iniciantes',
#   'categoria': 'Produtividade',
#   'carga_horaria': None,
#   'concluintes': None,
#   'data_inicio': None,
#   'data_conclusao': None,
#   'descricao': None,
#   'preco': None,
#   'instrutor': {'nome': 'Maria Oliveira',
#    'email': 'maria.oliveira@emailaleatorio.com',
#    'telefone': '(11) 8888-8888'}},
#  {'curso': 'Marketing digital para negócios',
#   'categoria': 'Marketing',
#   'carga_horaria': '30 horas',
#   'concluintes': 75,
#   'data_inicio': '2022-03-01',
#   'data_conclusao': '2022-03-31',
# ...

# %% [markdown]
# Normalizando os dados para um dataframe:

# %%
cursos = pd.json_normalize(cursos_json)
cursos
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
# 5         Introdução à programação    Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90      João Silva
# 1                                               None   None  Maria Oliveira
# ...

# %% [markdown]
# Verificando a quantidade de dados nulos por coluna:

# %%
cursos.isna().sum()
# Out:
# curso                 0
# categoria             0
# carga_horaria         1
# concluintes           1
# data_inicio           1
# data_conclusao        1
# descricao             1
# preco                 1
# instrutor.nome        0
# instrutor.email       0
# instrutor.telefone    0
# dtype: int64

# %% [markdown]
# Verificando quais linhas únicas possuem dados nulos:

# %%
cursos[cursos.isna().any(axis=1)]
# Out:
#                    curso      categoria carga_horaria concluintes data_inicio  \
# 1  Excel para iniciantes  Produtividade          None        None        None
#
#   data_conclusao descricao preco  instrutor.nome  \
# 1           None      None  None  Maria Oliveira
#
#                      instrutor.email instrutor.telefone
# 1  maria.oliveira@emailaleatorio.com     (11) 8888-8888

# %% [markdown]
# Removendo dados nulos:

# %%
cursos.dropna(inplace=True)

# %% [markdown]
# Checando dados nulos novamente:

# %%
cursos.isna().sum()
# Out:
# curso                 0
# categoria             0
# carga_horaria         0
# concluintes           0
# data_inicio           0
# data_conclusao        0
# descricao             0
# preco                 0
# instrutor.nome        0
# instrutor.email       0
# instrutor.telefone    0
# dtype: int64

# %% [markdown]
# Deu certo, agora iremos verificar se existem dados duplicados.

# %%
cursos.duplicated()
# Out:
# 0    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %% [markdown]
# Como podemos ver o último item deu True, portanto é duplicado. Então vamos removê-lo.

# %%
cursos.drop_duplicates(inplace=True)

# %%
cursos.duplicated()
# Out:
# 0    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# Pronto, não existem mais ítens duplicados. Agora iremos verficar a existência de valores vazios.

# %%
cursos.eq('').any()
# Out:
# curso                 False
# categoria             False
# carga_horaria         False
# concluintes            True
# data_inicio            True
# data_conclusao         True
# descricao             False
# preco                 False
# instrutor.nome         True
# instrutor.email        True
# instrutor.telefone     True
# dtype: bool

# %%
cursos
# Out:
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
# 3          Inteligência artificial  Programação      40 horas
# 4             Inglês para negócios      Idiomas      20 horas          30
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
#
#                                            descricao  preco instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90     João Silva
# 2                    Curso introdutório em marketing   89.9     Ana Santos
# 3  Curso avançado sobre inteligência artificial c...  129.9
# 4                      Curso de inglês para negócios   69.9     John Smith
#
#                  instrutor.email instrutor.telefone
# 0  joao.silva@emailaleatorio.com     (11) 9999-9999
# ...

# %% [markdown]
# Para facilitar nosso processo, vamos substituir os valores vazios por valores nulos.

# %%
cursos.replace('', pd.NA, inplace=True)

# %% [markdown]
# Agora podemos utilizar o método específico de remoção de valores nulos, que utilizamos anteriormente.

# %%
cursos.dropna(inplace=True)

# %%
cursos
# Out:
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
#
#   data_inicio data_conclusao                                    descricao  \
# 0  2022-01-01     2022-01-20  Curso introdutório à programação com Python
# 2  2022-03-01     2022-03-31              Curso introdutório em marketing
#
#    preco instrutor.nome                instrutor.email instrutor.telefone
# 0  99.90     João Silva  joao.silva@emailaleatorio.com     (11) 9999-9999
# 2   89.9     Ana Santos  ana.santos@emailaleatorio.com     (11) 7777-7777

# %% [markdown]
# Pronto agora não temos mais valores vazios, nulos e duplicados. Agora iremos para última etapa, que é a de fazer o *cast* das colunas para seus tipos corretos.

# %%
cursos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 0 to 2
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               2 non-null      object
#  1   categoria           2 non-null      object
#  2   carga_horaria       2 non-null      object
#  3   concluintes         2 non-null      object
#  4   data_inicio         2 non-null      object
#  5   data_conclusao      2 non-null      object
#  6   descricao           2 non-null      object
#  7   preco               2 non-null      object
#  8   instrutor.nome      2 non-null      object
#  9   instrutor.email     2 non-null      object
#  10  instrutor.telefone  2 non-null      object
# dtypes: object(11)
# memory usage: 192.0+ bytes

# %%
cursos['concluintes'] = cursos['concluintes'].astype(int)

# %%
cursos['data_inicio'] = pd.to_datetime(cursos['data_inicio'])
cursos['data_conclusao'] = pd.to_datetime(cursos['data_conclusao'])

# %%
cursos['preco'] = cursos['preco'].astype(float)

# %%
cursos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 0 to 2
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               2 non-null      object
#  1   categoria           2 non-null      object
#  2   carga_horaria       2 non-null      object
#  3   concluintes         2 non-null      int64
#  4   data_inicio         2 non-null      datetime64[ns]
#  5   data_conclusao      2 non-null      datetime64[ns]
#  6   descricao           2 non-null      object
#  7   preco               2 non-null      float64
#  8   instrutor.nome      2 non-null      object
#  9   instrutor.email     2 non-null      object
#  10  instrutor.telefone  2 non-null      object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(7)
# memory usage: 192.0+ bytes

# %% [markdown]
# Pronto, agora temos as colunas em suas tipagens corretas para análise de dados.

# %% [markdown]
# ## **Desafio 4** - Identificando fraudes

# %% [markdown]
# Você trabalha em um banco como cientista de dados e recebeu o seguinte conjunto de dados para analisar:

# %%
df = pd.DataFrame({
    'ID da transação': range(1, 31),
    'Valor da transação': [100, 200, 150, 500, 300, 913, 250, 400, 200, 150,
                           200, 200, 400, 300, 150, 301, 805, 300, 400, 250,
                           150, 100, 500, 600, 200, 350, 100, 250, 800, 250],
    'Data da transação': pd.date_range(start='2022-01-01', end='2022-01-30', freq='D'),
    'Local da transação': ['São Paulo, Brasil', 'Rio de Janeiro, Brasil', 'Belo Horizonte, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'Nova Iorque, EUA', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'Rio de Janeiro, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'Los Angeles, EUA', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'Miami, EUA', 'São Paulo, Brasil']
})

# %% [markdown]
# > Foi informado que nessa base de dados há possíveis fraudes que podem ser identificadas através dos outliers no “valor da transação”. Basicamente a fraude seria um outlier.
#
# > Sua missão é construir uma função que recebe dois parâmetros, a coluna que você quer analisar se tem outlier e o DataFrame em questão. A intenção de fazer isso é aproveitar novamente essa função tanto para outras colunas quanto para outros DataFrames futuramente em outras análises. O método que deve ser implementado para identificação do outlier é do intervalo interquartil.

# %%
def calc_outliers(column, dataframe):

  # calculando o IQR e definindo o limite para outliers
  Q1 = dataframe[column].quantile(0.25)
  Q3 = dataframe[column].quantile(0.75)
  IQR = Q3 - Q1
  limite_inferior = Q1 - 1.5 * IQR
  limite_superior = Q3 + 1.5 * IQR

  # identificando os outliers
  outliers = dataframe[(dataframe[column] < limite_inferior) | (dataframe[column] > limite_superior)]

  # retornando os outliers
  return outliers

# %%
print(calc_outliers('Valor da transação', df))
# Out:
#     ID da transação  Valor da transação Data da transação Local da transação
# 5                 6                 913        2022-01-06   Nova Iorque, EUA
# 16               17                 805        2022-01-17   Los Angeles, EUA
# 28               29                 800        2022-01-29         Miami, EUA
